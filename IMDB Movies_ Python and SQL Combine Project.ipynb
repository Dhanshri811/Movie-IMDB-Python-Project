# %%
import mysql.connector

# %%
mydb= mysql.connector.connect(host= 'localhost', user='root', password ='Pass@123', database= 'Python_Connector')

# %%
mycursor = mydb.cursor()

# %%
a= ("select Title from Movies  ;")
mycursor.execute(a)

# %%
for (Title) in mycursor:
    print(Title)
# Out:
# ('Guardians of the Galaxy',)
# ('Prometheus',)
# ('Split',)
# ('Sing',)
# ('Suicide Squad',)
# ('The Great Wall',)
# ('La La Land',)
# ('The Lost City of Z',)
# ('Passengers',)
# ('Fantastic Beasts and Where to Find Them',)
# ('Hidden Figures',)
# ('Rogue One',)
# ('Moana',)
# ('Colossal',)
# ('The Secret Life of Pets',)
# ('Hacksaw Ridge',)
# ('Jason Bourne',)
# ('Lion',)
# ('Arrival',)
# ('Gold',)
# ('Manchester by the Sea',)
# ('Trolls',)
# ('Independence Day: Resurgence',)
# ('Bad Moms',)
# ("Assassin's Creed",)
# ('Why Him?',)
# ('Nocturnal Animals',)
# ('X-Men: Apocalypse',)
# ('Deadpool',)
# ('Resident Evil: The Final Chapter',)
# ('Captain America: Civil War',)
# ('Interstellar',)
# ('Doctor Strange',)
# ('The Magnificent Seven',)
# ('Sausage Party',)
# ('Moonlight',)
# ('The Founder',)
# ('Lowriders',)
# ('Pirates of the Caribbean: On Stranger Tides',)
# ('Miss Sloane',)
# ('Star Trek Beyond',)
# ('Star Wars: Episode VII - The Force Awakens',)
# ('Underworld: Blood Wars',)
# ...

# %% [markdown]
# ## Titles having Runtime is graeter than 180 Minutes

# %%
a= ("select Title, `Runtime (Minutes)` from Movies where `Runtime (Minutes)` >=180 ;")
mycursor.execute(a)

# %%
for (Title) in mycursor:
    print(Title)
# Out:
# ('The Wolf of Wall Street', 180)
# ('The Hateful Eight', 187)
# ("La vie d'Adèle", 180)

# %% [markdown]
# ## In which year, there was a highest average voting?

# %%
a= ("Select Year, avg(Votes) from Movies group by Year order by avg(Votes) desc;")
mycursor.execute(a)

# %%
for (Year) in mycursor:
    print(Year)
# Out:
# (2012, Decimal('290861.4839'))
# (2006, Decimal('281279.1500'))
# (2009, Decimal('267180.5778'))
# (2008, Decimal('266580.1458'))
# (2007, Decimal('266530.7045'))
# (2010, Decimal('261082.9298'))
# (2011, Decimal('259254.7368'))
# (2013, Decimal('225531.8929'))
# (2014, Decimal('212471.8132'))
# (2015, Decimal('130207.2804'))
# (2016, Decimal('68852.9026'))

# %%
a= ("Select Year, avg(Votes) as avg_votes from Movies group by Year order by avg(Votes) desc;")
df = pd.read_sql(a, mydb)
# Out:
# /tmp/ipykernel_26400/385012380.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(a, mydb)

# %%
ax= df.plot.bar(x="Year", y="avg_votes", rot=0)

# %% [markdown]
# ## Yearwise highest revenue

# %%
a= ("Select Year, Sum(`Revenue (Millions)`) as total_revenue from Movies group by Year order by Sum(`Revenue (Millions)`) desc;")
mycursor.execute(a)

# %%
for (Year) in mycursor:
    print(Year)
# Out:
# (2016, 10847.070000000003)
# (2015, 8755.810000000001)
# (2014, 7856.829999999998)
# (2013, 7399.109999999997)
# (2012, 6826.390000000002)
# (2010, 5989.650000000001)
# (2011, 5341.090000000001)
# (2009, 5208.39)
# (2008, 4681.220000000001)
# (2007, 4095.2599999999998)
# (2006, 3577.040000000001)

# %%
a= ("Select Year, Sum(`Revenue (Millions)`) as total_revenue from Movies group by Year order by Sum(`Revenue (Millions)`) desc;")
df = pd.read_sql(a, mydb)
# Out:
# /tmp/ipykernel_26400/750987110.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(a, mydb)

# %%
ax= df.plot.bar(x="Year", y="total_revenue", rot=0)
ax.set_ylabel("Revenue")
ax.set_title("Yearwise Revenue")
# Out:
# Text(0.5, 1.0, 'Yearwise Revenue')

# %% [markdown]
# ## Average rating for each director

# %%
a= ("Select Director, Avg(Rating) as avg_rating from Movies group by Director order by avg_rating desc;")
mycursor.execute(a)

# %%
for (Director) in mycursor:
    print(Director)
# Out:
# ('Christopher Nolan', 8.680000000000001)
# ('Makoto Shinkai', 8.6)
# ('Olivier Nakache', 8.6)
# ('Florian Henckel von Donnersmarck', 8.5)
# ('Aamir Khan', 8.5)
# ('Damien Chazelle', 8.4)
# ('Rajkumar Hirani', 8.3)
# ('Thomas Vinterberg', 8.3)
# ('Lee Unkrich', 8.3)
# ('Pete Docter', 8.25)
# ('Lenny Abrahamson', 8.2)
# ('Juan José Campanella', 8.2)
# ('Quentin Tarantino', 8.166666666666666)
# ('Garth Davis', 8.1)
# ('Byron Howard', 8.1)
# ('Chan-wook Park', 8.1)
# ('Tom McCarthy', 8.1)
# ('Sean Penn', 8.1)
# ('Xavier Dolan', 8.1)
# ('Damián Szifron', 8.1)
# ('Mel Gibson', 8.0)
# ('Tim Miller', 8.0)
# ('Spike Jonze', 8.0)
# ('Stephen Chbosky', 8.0)
# ('Dean DeBlois', 8.0)
# ('Martin Scorsese', 7.92)
# ('Kenneth Lonergan', 7.9)
# ('Matt Ross', 7.9)
# ('Dan Gilroy', 7.9)
# ('Travis Knight', 7.9)
# ('Taika Waititi', 7.9)
# ('Wes Anderson', 7.8999999999999995)
# ('Anthony Russo', 7.85)
# ('Alfonso Cuarón', 7.85)
# ('Gabriele Muccino', 7.85)
# ('David Fincher', 7.8199999999999985)
# ...

# %%
a= ("Select Director, Avg(Rating) as avg_rating from Movies group by Director order by avg_rating desc limit 10;")
df = pd.read_sql(a, mydb)
# Out:
# /tmp/ipykernel_26400/2170928184.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(a, mydb)

# %%
ax = df.plot(kind='bar', x='Director', y='avg_rating', figsize=(10, 6))
ax.set_ylabel("Rating")
ax.set_title("Top 10 Director")
# Out:
# Text(0.5, 1.0, 'Top 10 Director')

# %% [markdown]
# # Top 10 lengthy movie and their Runtime

# %%
a= ("Select Title, `Runtime (Minutes)` as Runtime from Movies  order by Runtime desc limit 10;")
mycursor.execute(a)

# %%
for (Title) in mycursor:
    print(Title)
# Out:
# ('The Hateful Eight', 187)
# ('The Wolf of Wall Street', 180)
# ("La vie d'Adèle", 180)
# ('Cloud Atlas', 172)
# ('3 Idiots', 170)
# ("Pirates of the Caribbean: At World's End", 169)
# ('Interstellar', 169)
# ('The Hobbit: An Unexpected Journey', 169)
# ('The Curious Case of Benjamin Button', 166)
# ('Django Unchained', 165)

# %%
a= ("Select Title, `Runtime (Minutes)` as Runtime from Movies  order by Runtime desc limit 10;")
df = pd.read_sql(a, mydb)
# Out:
# /tmp/ipykernel_26400/3752813908.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(a, mydb)

# %%
ax = df.plot(kind='bar', x='Title', y='Runtime', figsize=(10, 6))
ax.set_ylabel("Runtime")
ax.set_title("Top 10 Lengthy Movies")
# Out:
# Text(0.5, 1.0, 'Top 10 Lengthy Movies')

# %% [markdown]
# ## Number of movies per Year

# %%
a= ('select Year, count(Title) as Total_count from Movies group by Year order by Total_count desc; ')
mycursor.execute(a)

# %%
for (Year) in mycursor:
    print(Year)
# Out:
# (2016, 195)
# (2015, 107)
# (2014, 91)
# (2013, 84)
# (2012, 62)
# (2011, 57)
# (2010, 57)
# (2008, 48)
# (2009, 45)
# (2007, 44)
# (2006, 40)

# %%
a= ('select Year, count(Title) as Total_count from Movies group by Year order by Total_count desc; ')
df= pd.read_sql(a, mydb)
# Out:
# /tmp/ipykernel_26400/3520366343.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df= pd.read_sql(a, mydb)

# %%
ax = df.plot(kind= 'bar', x= 'Year', y= 'Total_count', figsize=(10,6))
ax.set_title('Count of Movies per Year')
ax.set_ylabel('Number of Movies')
# Out:
# Text(0, 0.5, 'Number of Movies')

# %%
sns.barplot(x= 'Year', y= 'Total_count', data= df) #by using sns 
plt.figure(figsize = (15,8))

# %% [markdown]
# ## Top 10 Highest Movie Title and its Director

# %%
a= ('select Title, Director, Rating from Movies order by Rating desc limit 10;')
mycursor.execute(a)

# %%
for (Title) in mycursor:
    print(Title)
# Out:
# ('The Dark Knight', 'Christopher Nolan', 9.0)
# ('Inception', 'Christopher Nolan', 8.8)
# ('Interstellar', 'Christopher Nolan', 8.6)
# ('Kimi no na wa', 'Makoto Shinkai', 8.6)
# ('The Intouchables', 'Olivier Nakache', 8.6)
# ('The Prestige', 'Christopher Nolan', 8.5)
# ('Whiplash', 'Damien Chazelle', 8.5)
# ('The Dark Knight Rises', 'Christopher Nolan', 8.5)
# ('The Departed', 'Martin Scorsese', 8.5)
# ('Taare Zameen Par', 'Aamir Khan', 8.5)

# %%
a= ('select Title, Director, Rating from Movies order by Rating desc limit 10;')
df= pd.read_sql(a,mydb)
# Out:
# /tmp/ipykernel_26400/1255418825.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df= pd.read_sql(a,mydb)

# %%
sns.barplot(x= 'Rating', y= 'Title',hue= 'Director', dodge= False, data= df)
plt.legend(bbox_to_anchor=(1.05,1), loc=2)

# %% [markdown]
# ## Top 10 Highest Revenue Movie Title

# %%
a= ('Select Title, `Revenue (Millions)` as Revenue from Movies order by Revenue desc limit 10;')
mycursor.execute(a)

# %%
for (Title) in mycursor:
    print(Title)
# Out:
# ('Star Wars: Episode VII - The Force Awakens', 936.63)
# ('Avatar', 760.51)
# ('Jurassic World', 652.18)
# ('The Avengers', 623.28)
# ('The Dark Knight', 533.32)
# ('Rogue One', 532.17)
# ('Finding Dory', 486.29)
# ('Avengers: Age of Ultron', 458.99)
# ('The Dark Knight Rises', 448.13)
# ('The Hunger Games: Catching Fire', 424.65)

# %%
a= ('Select Title, `Revenue (Millions)` as Revenue from Movies order by Revenue desc limit 10;')
df= pd.read_sql(a,mydb)
# Out:
# /tmp/ipykernel_26400/1014382524.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df= pd.read_sql(a,mydb)

# %%
sns.barplot(x= 'Revenue', y = 'Title', data = df)
plt.figure(figsize = (18,5))

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
